# %% [markdown]
# ## Overview
#
# ![alt text](https://i.imgur.com/x6NMN9Q.png "Logo Title Text 1")
#
# - TrustToken is a platform to create asset-backed tokens that you can easily buy and sell around the world.
# - You can use it to tokenize everything,. Real Estate, real estate, businesses, private equity, patents, copyrights, sports teams, collectible art, and commodities such as gold and oil.
# - Democratizes access to investments and ability to raise capital
# - Blockchains coul help control and transact with the 256 trillion USD worth of real-world assets
# - TrustToken is legally enforced, audited, and collatorized.
# - The first asset token is TrueUSD (TUSD) a stablecoin that you can redeem 1-for-1 for U.S. dollars. TrueUSD is the only fully collateralized and fully compliant USD-backed stablecoin that is live for purchase, redemption, and trade.
# - CoinList sale is open.
# - TrueUSD is listed on the world's top cryptocurrency exchanges including Binance, Bittrex, HBUS, HitBTC, and Upbit. On HBUS and HitBTC, TUSD is a quote currency.
# - TrueUSD grew to over 40 million in market cap within 3 months of launching.
#
# ![alt text](https://icodrops.com/wp-content/uploads/2018/02/TrustToken-Benefits.jpg "Logo Title Text 1")
#
# ![alt text](https://icodrops.com/wp-content/uploads/2018/02/TrustToken-Team.jpg "Logo Title Text 1")
#
# ###### 5 Parts
#
# ![alt text](https://wiki.qointum.com/media/wiki/images/10/2ad3196750da487d8d4d48cb141de45c/qdpos.png "Logo Title Text 1")
#
# - SmartTrust, a type of legal contract that appoints beneficial asset ownership and control to a smart contract on a blockchain
# - TrustMarket, where clients can hire fiduciaries who interface with legal-financial institutions and are legally bound to manage assets as instructed by the smart contract
# - TrustProtocol, a protocol that specifies how smart contracts can direct fiduciaries
# - TrustVault, a decentralized and secure storage system for complete audit trails of asset transactions
# - TrustToken, the platform’s incentive layer to reward trustworthy behavior, create an audit trail, and collateralize property
#
# ![alt text](https://i.imgur.com/jOaHxGP.png "Logo Title Text 1")
#
# ###### The first SmartTrust was successfully launched in October 2017. It owns a bank account and is controlled by the Ethereum smart contract 0xa8efaa4d10be6211a0a5db4ccc9f22bd28ca60b3.
#
# ![alt text](https://i.imgur.com/WWfIkls.png "Logo Title Text 1")
#
# ## The Need for Stable Cryptocurrencies
#
# - The price volatility of cryptocurrencies prevents their widespread adoption.
#
# ![alt text](https://cdn-images-1.medium.com/max/1600/0*rwbu-s1qWliohCSw. "Logo Title Text 1")
#
# ![alt text](https://cdn-images-1.medium.com/max/1600/1*3uhi8kUIcDPn1YWW30dRyA.png "Logo Title Text 1")
#
# - Tether is currently the largest fiat-collateralized cryptocurrency.
# - Tether holders have no legal guarantee that Tethers can be redeemed for traditional currency.
# - Without legal penalties to offset misappropriation rewards, the risk of defection will rise with increasing asset tokenization.
#
# ![alt text](https://cdn-images-1.medium.com/max/1600/0*yz6kwOm8lN6n2p6v.png "Logo Title Text 1")
#
# - To comply with securities policies, TrustToken currently support Reg. D and Reg. CF offerings for security tokens.
# - This way, users know which legal precedents to follow, and can build on well-known frameworks for securitizing assets and funding businesses.
#
# ## Use cases
#
# ![alt text](https://cdn-images-1.medium.com/max/1600/1*giGe3yh7sAic9de3IDA8Vw.png "Logo Title Text 1")
#
# - A liquid, global market of tokenized real estate and rental properties
# - International access to local stock, bonds, and other financial instruments
# - Secure real estate transactions using smart contract escrow
# - Stable cryptocurrencies backed by fiat currencies or commodities
# - Early liquidity of intellectual property, such as patents, music, and software
#
# ## Architecture
#
# - The general solidity files are TokenWithFees.sol, TrueUSD.sol
#
# ![alt text](https://i.imgur.com/RFL7pev.png "Logo Title Text 1")
#
# #### To Buy (complianttoken.sol, TimeLockedController.sol)
# 1.  Complete the KYC/AML check
# - User submits personal info to TrustToken to get KYC/AML Clearance
# 2. Provide Ethereum address
# -  User provide the Ethereum address at which you want to receive TrueUSD tokens.
# 3. Wire funds
# - User wires funds directly to a TrueUSD escrow account (Owned by PrimeTrust)
# 4. Both Escrow + a group of 'stakers' verify the validity of the transaction
# 5. User Receives TrueUSD Tokens
#
# ![alt text](https://coinsutra.com/wp-content/uploads/2018/02/Bitcoin-Address-Burn-1.png "Logo Title Text 1")
#
# #### To Sell (burnabletoken.sol, withdrawal.sol, DelegateBurnable.sol, canDelegate.sol)
# 1. User burns tokens
# 2. Stakers verify transactions
# 3. User receives Fiat
#
#
# ![alt text](https://cdn-images-1.medium.com/max/1600/1*LAdhyn_9G9ybxXwXnV-wFw.png "Logo Title Text 1")
#
# ![alt text](https://cdn-images-1.medium.com/max/1600/0*fMiTDMePhiepg9Av. "Logo Title Text 1")
